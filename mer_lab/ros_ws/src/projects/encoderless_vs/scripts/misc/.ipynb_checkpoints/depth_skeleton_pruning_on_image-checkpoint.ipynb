# %%
import numpy as np
import cv2
from skimage.morphology import remove_small_objects, dilation, skeletonize, skeletonize_3d, medial_axis, binary_closing
from skimage.segmentation import clear_border
from skimage.filters import unsharp_mask, threshold_triangle, difference_of_gaussians
from skimage.graph import shortest_path, route_through_array
import matplotlib.pyplot as plt

# %%
#parameters

dmin = 1
dmax = 20

# r = [250, 50, 280, 170]
# r = [320, 60, 280, 190]
r = [257, 19, 362, 224]

# %%
# depth_img = cv2.imread('/home/janch-ros/Documents/video_images/frame0007.jpg')
depth_img = cv2.imread('/home/jani/Documents/pics/CV-Depth1.jpg')

# %%
# r = cv2.selectROI(depth_img)
# print(r)

# %%
depth_img_cropped = depth_img[r[1]:r[1]+r[3], r[0]:r[0]+r[2]]
# depth_img[0:300, 0:300] = 0
# depth_img[0:80, 230:230+370] = 0
# depth_img[0:480, 550:550+300] = 0
# depth_img[240:240+240, 0:848] = 0

# %%
# cv2.imshow("Depth Window 1", depth_img_cropped)
# cv2.waitKey(5000)
# cv2.imwrite('/home/janch-ros/Documents/video_images/depth_cropped_1.jpg', depth_img_cropped)
cv2.imwrite('/home/jani/Documents/depth_cropped_1.jpg', depth_img_cropped)
# Out:
# True

# %%
# r = cv2.selectROI(depth_img_cropped)
# print(r)
# depth_img_cropped = depth_img[r[1]:r[1]+r[3], r[0]:r[0]+r[2]]
# print(np.max(depth_img_cropped))

# %%
depth_img_cropped = np.where((depth_img_cropped < dmin) | (depth_img_cropped > dmax), 0, depth_img_cropped)
# cv2.imshow("Depth Window 2", depth_img_cropped)
# cv2.waitKey(2000)
depth = depth_img_cropped
kernel = np.ones((9, 9), np.uint8)
# blur = cv2.GaussianBlur(depth_img_cropped, (5,5), 0)
depth = cv2.dilate(depth, kernel, iterations=1)
depth = cv2.erode(depth, kernel, iterations=4)
# depth = cv2.morphologyEx(depth, cv2.MORPH_OPEN, kernel)

depth = cv2.morphologyEx(depth, cv2.MORPH_OPEN, kernel)

# %%
# cv2.imshow("Depth Window 3", depth)
# cv2.waitKey(5000)

# cv2.imwrite('/home/janch-ros/Documents/video_images/depth_gray_1.jpg', depth)
cv2.imwrite('/home/jani/Documents/depth_gray_1.jpg', depth)
# Out:
# True

# %%
binary = np.where(depth > 0, 1, depth)
skeleton = skeletonize(binary)
# skeleton = np.array(skeleton, dtype=np.uint8)  
skeleton = cv2.cvtColor(skeleton, cv2.COLOR_BGR2GRAY)
skeleton = np.where(skeleton == 1, 255, skeleton)
print(skeleton.shape)
# skeleton = cv2.cvtColor(skeleton, cv2.COLOR_GRAY2BGR)
# Out:
# (224, 362)

# %%
# cv2.imwrite('/home/janch-ros/Documents/video_images/depth_skel_1.jpg', skeleton)
cv2.imwrite('/home/jani/Documents/depth_skel_1.jpg', skeleton)
# Out:
# True

# %%
pixels = np.argwhere(skeleton == 255)

pixels = np.flip(pixels)

copy_pix = pixels

print(copy_pix)
# Out:
# [[221 188]
#  [220 188]
#  [219 188]
#  [218 188]
#  [217 188]
#  [216 187]
#  [215 187]
#  [214 186]
#  [213 185]
#  [212 185]
#  [211 185]
#  [210 185]
#  [209 184]
#  [208 184]
#  [207 183]
#  [206 182]
#  [205 182]
#  [204 182]
#  [203 181]
#  [202 180]
#  [201 179]
#  [200 178]
#  [199 177]
#  [198 176]
#  [197 175]
#  [198 174]
#  [198 173]
#  [199 172]
#  [199 171]
#  [199 170]
#  [200 169]
#  [200 168]
#  [200 167]
#  [200 166]
#  [200 165]
#  [200 164]
#  [200 163]
#  [200 162]
#  [200 161]
#  [201 160]
#  [201 159]
#  [201 158]
#  [201 157]
#  [202 156]
#  [202 155]
#  [202 154]
#  [203 153]
#  [203 152]
#  [204 151]
#  [205 150]
#  [207 149]
#  [206 149]
#  [208 148]
#  [209 147]
#  [210 146]
#  [212 145]
#  [211 145]
#  [213 144]
#  [213 143]
#  [214 142]
#  [215 141]
#  [215 140]
#  [216 139]
#  [216 138]
#  [217 137]
#  [217 136]
#  [217 135]
#  [218 134]
#  [218 133]
#  [238 132]
#  [237 132]
#  [218 132]
#  [236 131]
#  [235 131]
#  [234 131]
#  [218 131]
# ...

# %%
initial_pos = pixels[0] #extract the center of the base marker and get initial position    
row_index, = np.where(np.all(copy_pix == [initial_pos], axis=1))
copy_pix = np.delete(copy_pix, row_index, axis=0)
print(copy_pix[0])
point_len = len(copy_pix)    
ordered = initial_pos
print(ordered)
# print(copy_pix[:,1])
# Out:
# [264 153]
# [264 154]

# %%
while len(copy_pix)>0:
    distances = np.sqrt((copy_pix[:,0] - initial_pos[0]) ** 2 + (copy_pix[:,1] - initial_pos[1]) ** 2)
#     print(distances)
    nearest_index = np.argmin(distances)
    print("Point {} matched with {}".format(initial_pos, copy_pix[nearest_index]))
    print("Nearest index: {}".format(nearest_index))
    initial_pos = copy_pix[nearest_index] #(target[0], target[1])
    print("Initial Pose", initial_pos)
    copy_pix = np.delete(copy_pix, nearest_index, axis=0)
#     print(copy_pix[0])
    point_len = len(copy_pix)
    ordered = np.append(ordered, [initial_pos])
print(ordered)
# Out:
# Point [264 154] matched with [264 153]
# Nearest index: 0
# Initial Pose [264 153]
# Point [264 153] matched with [264 152]
# Nearest index: 0
# Initial Pose [264 152]
# Point [264 152] matched with [264 151]
# Nearest index: 0
# Initial Pose [264 151]
# Point [264 151] matched with [264 150]
# Nearest index: 0
# Initial Pose [264 150]
# Point [264 150] matched with [264 149]
# Nearest index: 0
# Initial Pose [264 149]
# Point [264 149] matched with [264 148]
# Nearest index: 0
# Initial Pose [264 148]
# Point [264 148] matched with [264 147]
# Nearest index: 0
# Initial Pose [264 147]
# Point [264 147] matched with [264 146]
# Nearest index: 0
# Initial Pose [264 146]
# Point [264 146] matched with [264 145]
# Nearest index: 0
# Initial Pose [264 145]
# Point [264 145] matched with [264 144]
# Nearest index: 0
# Initial Pose [264 144]
# Point [264 144] matched with [264 143]
# Nearest index: 0
# Initial Pose [264 143]
# Point [264 143] matched with [264 142]
# Nearest index: 0
# ...

# %%

    fig = plt.figure()
    ax = fig.add_subplot(111)
    fig.show()
    fig.canvas.draw()
ax.clear()
ax.set_xlim([0, 300])
ax.set_ylim([-300, 0])
# ax.set_ylim([0, 300])

ax.plot(y[0:51], -x[0:51], 'b+', label='Data')
ax.plot(y[51:101], -x[51:101], 'r+', label='Data')
ax.plot(y[101:151], -x[101:151], 'g+', label='Data')
ax.plot(y[151:201], -x[151:201], 'c+', label='Data')
ax.plot(y[201:251], -x[201:251], 'k+', label='Data')
ax.plot(y[251:301], -x[251:301], 'bo', label='Data')
ax.plot(y[301:-1], -x[301:-1], 'ro', label='Data')
# Out:
# /tmp/ipykernel_24485/4092672185.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# skeleton = skeleton[0::5]
(rows,cols) = np.nonzero(skeleton)
print(rows)
print(cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24485/2931854140.py in <module>
#       1 # skeleton = skeleton[0::5]
# ----> 2 (rows,cols) = np.nonzero(skeleton)
#       3 print(rows)
#       4 print(cols)
#       5
#
# NameError: name 'skeleton' is not defined

# %%
skel_coords = []
intersection = []

for (r,c) in zip(rows,cols):

    # Extract an 8-connected neighbourhood
    (col_neigh,row_neigh) = np.meshgrid(np.array([c-1,c,c+1]), np.array([r-1,r,r+1]))
    # Cast to int to index into image
#     col_neigh = np.array([c-1, c, c+1])
    col_neigh = col_neigh.astype('int')
    print(col_neigh)
#     row_neigh = np.array([r-1,r,r+1])
    row_neigh = row_neigh.astype('int')
    print(row_neigh)

    # Convert into a single 1D array and check for non-zero locations
    print(skeleton[row_neigh,col_neigh].ravel())
    pix_nbhood = skeleton[row_neigh,col_neigh].ravel() != 0 
    print(pix_nbhood)
    print(np.sum(pix_nbhood))

    # If the number of non-zero locations equals 2, add this to 
    # our list of co-ordinates for end points
    if np.sum(pix_nbhood) < 3:
#         print(np.sum(pix_nbhood))
        skel_coords.append((c,r))
    # our list of co-ordinates for intersection points
    elif np.sum(pix_nbhood) > 3:
#         print(np.sum(pix_nbhood))
        intersection.append((c,r))
# Out:
# [[179 180 181]
#  [179 180 181]
#  [179 180 181]]
# [[46 46 46]
#  [47 47 47]
#  [48 48 48]]
# [  0   0   0   0 255   0   0 255   0]
# [False False False False  True False False  True False]
# 2
# [[179 180 181]
#  [179 180 181]
#  [179 180 181]]
# [[47 47 47]
#  [48 48 48]
#  [49 49 49]]
# [  0 255   0   0 255   0   0 255   0]
# [False  True False False  True False False  True False]
# 3
# [[179 180 181]
#  [179 180 181]
#  [179 180 181]]
# [[48 48 48]
#  [49 49 49]
#  [50 50 50]]
# [  0 255   0   0 255   0   0   0 255]
# [False  True False False  True False False False  True]
# 3
# [[180 181 182]
#  [180 181 182]
#  [180 181 182]]
# [[49 49 49]
#  [50 50 50]
#  [51 51 51]]
# [255   0   0   0 255   0   0 255   0]
# [ True False False False  True False False  True False]
# 3
# [[180 181 182]
#  [180 181 182]
#  [180 181 182]]
# [[50 50 50]
#  [51 51 51]
#  [52 52 52]]
# [  0 255   0   0 255   0   0 255   0]
# [False  True False False  True False False  True False]
# 3
# ...

# %%
# # Initialize empty list of co-ordinates
        
print(skel_coords)
print(intersection)
# Out:
# [(180, 47), (126, 71), (264, 154)]
# [(183, 68)]

# %%
skeleton = cv2.cvtColor(skeleton, cv2.COLOR_GRAY2BGR)

cv2.circle(skeleton,(skel_coords[0]),3,(0,0,255),-1) 
cv2.circle(skeleton,(skel_coords[1]),3,(0,255,0),-1)
cv2.circle(skeleton,(skel_coords[2]),5,(255,255,255),-1)
cv2.circle(skeleton,(intersection[0]),5,(255,0,0),-1) 

cv2.imwrite('/home/janch-ros/Documents/video_images/skel_corner_1.jpg', skeleton)
# Out:
# True

# %%
pixels = ordered
pix = pixels.tolist()
print(pix)
new_pix = []
# Out:
# [[264, 154], [264, 153], [264, 152], [264, 151], [264, 150], [264, 149], [264, 148], [264, 147], [264, 146], [264, 145], [264, 144], [264, 143], [264, 142], [264, 141], [264, 140], [264, 139], [264, 138], [264, 137], [264, 136], [264, 135], [264, 134], [264, 133], [264, 132], [264, 131], [264, 130], [264, 129], [264, 128], [264, 127], [264, 126], [264, 125], [263, 124], [263, 123], [263, 122], [262, 121], [262, 120], [261, 119], [261, 118], [260, 117], [260, 116], [260, 115], [260, 114], [260, 113], [260, 112], [260, 111], [260, 110], [260, 109], [259, 108], [259, 107], [259, 106], [258, 105], [258, 104], [257, 103], [257, 102], [256, 101], [256, 100], [255, 99], [254, 98], [254, 97], [253, 96], [253, 95], [253, 94], [252, 93], [251, 92], [250, 91], [249, 90], [248, 89], [247, 88], [246, 87], [245, 86], [245, 85], [244, 84], [243, 83], [242, 82], [241, 81], [240, 80], [239, 79], [238, 79], [237, 79], [236, 79], [235, 79], [234, 79], [233, 79], [232, 79], [231, 79], [230, 79], [229, 7
# ...

# %%
base_index = pix.index([skel_coords[-1][0],skel_coords[-1][1]])
end_ind1 = pix.index([skel_coords[0][0],skel_coords[0][1]])
end_ind2 = pix.index([skel_coords[1][0],skel_coords[1][1]])
mid_index = pix.index([intersection[0][0], intersection[0][1]])

print(end_ind1, end_ind2, base_index, mid_index)
# Out:
# 152 209 0 131

# %%
# pix1 = pix[3:153]
# pix2 = pix[153:203]
# pix3 = pix[131:209]

if end_ind1 > end_ind2:
    short_pix = pix[mid_index+1:end_ind2+1]
else:
    short_pix = pix[mid_index+1:end_ind1+1]

# %%
pix = [ele for ele in pix if ele not in short_pix]

# %%
pts = (np.reshape(pix, (-1, 2))).tolist()
points = np.array(pts)

new_img = np.zeros((300, 300, 3), dtype = "uint8")

for i in range(len(points)):
    x = np.int(points[i][0])
    y = np.int(points[i][1])
    cv2.circle(new_img,(x, y),0,(255,255,255),-1) 

cv2.imwrite('/home/janch-ros/Documents/video_images/skel_branch_1.jpg', new_img)
# Out:
# True
