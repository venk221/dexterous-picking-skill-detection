# %%
import cv2
import cv2.aruco as aruco

# %%
image = cv2.imread('/home/jani/Documents/pics/CV-Depth150.tiff') 

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 

cv2.imwrite('aruco_gray.jpg', gray) 

aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50) 

arucoParameters = aruco.DetectorParameters_create() 

corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, aruco_dict, parameters=arucoParameters) 

print(ids) 

frame = aruco.drawDetectedMarkers(image, corners) 

# rej_frame = aruco.drawDetectedMarkers(image, rejectedImgPoints, borderColor=(100, 0, 240)) 

cv2.imwrite('aruco_display.jpg', frame)
# Out:
# [[34]
#  [32]]
# True

# %%
print(corners)
# Out:
# [array([[[420., 361.],
#         [444., 361.],
#         [444., 386.],
#         [419., 386.]]], dtype=float32), array([[[236., 108.],
#         [261., 107.],
#         [263., 131.],
#         [238., 133.]]], dtype=float32)]

# %%
x1 = int (corners[0][0][0][0]) 
y1 = int (corners[0][0][0][1])

# %%
print(x1, y1)
# Out:
# 420 361

# %%
x2 = int (corners[1][0][0][0]) 
y2 = int (corners[1][0][0][1])

# %%
print(x2, y2)
# Out:
# 236 108

# %%
cv2.circle(frame,(x1, y1),0,(255,0,0),-1)

cv2.imwrite('aruco_corners.jpg', frame)
# Out:
# True

# %%
# Out:
# 236 108

# %%
for i in range(64, 207):
    image = cv2.imread('/home/jani/Documents/pics/CV-Depth' + str(i)+'.tiff')
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 

    cv2.imwrite('aruco_gray.jpg', gray) 

    aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50) 

    arucoParameters = aruco.DetectorParameters_create() 

    corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, aruco_dict, parameters=arucoParameters) 

    print("for i = ", i, "id is ", ids) 

    frame = aruco.drawDetectedMarkers(image, corners) 

#     rej_frame = aruco.drawDetectedMarkers(image, rejectedImgPoints, borderColor=(100, 0, 240)) 

    cv2.imwrite('aruco_display' + str(i) + '.tiff', frame)
# Out:
# for i =  64 id is  None
# for i =  65 id is  [[34]]
# for i =  66 id is  None
# for i =  67 id is  None
# for i =  68 id is  None
# for i =  69 id is  None
# for i =  70 id is  None
# for i =  71 id is  None
# for i =  72 id is  None
# for i =  73 id is  None
# for i =  74 id is  None
# for i =  75 id is  None
# for i =  76 id is  None
# for i =  77 id is  None
# for i =  78 id is  None
# for i =  79 id is  None
# for i =  80 id is  None
# for i =  81 id is  None
# for i =  82 id is  None
# for i =  83 id is  None
# for i =  84 id is  None
# for i =  85 id is  None
# for i =  86 id is  None
# for i =  87 id is  [[34]]
# for i =  88 id is  None
# for i =  89 id is  None
# for i =  90 id is  None
# for i =  91 id is  None
# for i =  92 id is  None
# for i =  93 id is  None
# for i =  94 id is  None
# for i =  95 id is  None
# for i =  96 id is  None
# for i =  97 id is  [[34]]
# for i =  98 id is  None
# for i =  99 id is  [[34]]
# for i =  100 id is  None
# for i =  101 id is  None
# for i =  102 id is  None
# for i =  103 id is  None
# for i =  104 id is  [[34]]
# for i =  105 id is  [[34]]
# for i =  106 id is  [[34]]
# for i =  107 id is  [[34]]
# for i =  108 id is  [[34]]
# for i =  109 id is  None
# for i =  110 id is  None
# for i =  111 id is  [[34]]
# for i =  112 id is  [[34]]
# for i =  113 id is  [[32]]
# for i =  114 id is  None
# for i =  115 id is  None
# for i =  116 id is  [[34]
#  [32]]
# for i =  117 id is  None
# for i =  118 id is  [[34]]
# for i =  119 id is  [[34]]
# for i =  120 id is  [[34]]
# for i =  121 id is  [[34]]
# for i =  122 id is  [[32]]
# for i =  123 id is  [[34]]
# for i =  124 id is  [[34]
#  [32]]
# for i =  125 id is  [[34]]
# for i =  126 id is  [[34]
#  [32]]
# for i =  127 id is  None
# for i =  128 id is  [[34]]
# for i =  129 id is  [[34]]
# for i =  130 id is  [[34]]
# for i =  131 id is  [[34]]
# for i =  132 id is  [[34]]
# for i =  133 id is  [[34]]
# for i =  134 id is  [[34]]
# for i =  135 id is  [[34]]
# for i =  136 id is  [[34]]
# for i =  137 id is  [[34]
#  [32]]
# for i =  138 id is  None
# for i =  139 id is  [[34]]
# for i =  140 id is  [[34]]
# for i =  141 id is  [[34]]
# for i =  142 id is  None
# for i =  143 id is  [[34]]
# for i =  144 id is  [[34]]
# for i =  145 id is  [[34]]
# for i =  146 id is  [[34]
#  [32]]
# for i =  147 id is  [[34]]
# for i =  148 id is  [[34]]
# for i =  149 id is  [[34]]
# for i =  150 id is  [[34]
#  [32]]
# for i =  151 id is  [[34]]
# for i =  152 id is  [[34]
#  [32]]
# for i =  153 id is  [[34]]
# for i =  154 id is  [[34]
#  [32]]
# for i =  155 id is  [[34]]
# for i =  156 id is  [[34]]
# for i =  157 id is  [[34]]
# for i =  158 id is  [[34]]
# for i =  159 id is  [[34]]
# for i =  160 id is  [[34]
#  [32]]
# for i =  161 id is  [[34]
#  [32]]
# for i =  162 id is  [[34]]
# for i =  163 id is  [[34]]
# for i =  164 id is  [[34]]
# for i =  165 id is  [[34]
#  [32]]
# for i =  166 id is  [[34]
#  [32]]
# for i =  167 id is  [[34]]
# for i =  168 id is  [[34]
#  [32]]
# for i =  169 id is  [[34]]
# for i =  170 id is  [[34]]
# for i =  171 id is  [[34]
#  [32]]
# for i =  172 id is  [[34]]
# for i =  173 id is  [[34]]
# for i =  174 id is  [[34]]
# for i =  175 id is  [[34]]
# for i =  176 id is  [[34]
#  [32]]
# for i =  177 id is  [[34]
#  [32]]
# for i =  178 id is  [[34]
#  [32]]
# for i =  179 id is  [[34]
#  [32]]
# for i =  180 id is  [[34]
#  [32]]
# for i =  181 id is  [[34]]
# for i =  182 id is  [[34]]
# for i =  183 id is  [[34]
#  [32]]
# for i =  184 id is  [[34]
#  [32]]
# for i =  185 id is  [[34]]
# for i =  186 id is  [[34]
#  [32]]
# for i =  187 id is  [[34]]
# for i =  188 id is  [[34]
#  [32]]
# for i =  189 id is  [[34]]
# for i =  190 id is  [[34]]
# for i =  191 id is  [[34]
#  [32]]
# for i =  192 id is  [[34]
#  [32]]
# for i =  193 id is  [[34]
#  [32]]
# for i =  194 id is  [[34]
#  [32]]
# for i =  195 id is  [[34]
#  [32]]
# for i =  196 id is  [[34]
#  [32]]
# for i =  197 id is  [[34]
#  [32]]
# for i =  198 id is  [[34]]
# for i =  199 id is  [[34]]
# for i =  200 id is  [[34]
#  [32]]
# for i =  201 id is  [[34]
#  [32]]
# for i =  202 id is  [[34]]
# for i =  203 id is  [[34]
#  [32]]
# for i =  204 id is  [[34]]
# for i =  205 id is  [[34]
#  [32]]
# for i =  206 id is  [[34]]
